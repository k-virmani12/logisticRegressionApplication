# %%
import sys
import numpy
import matplotlib
import seaborn
import sklearn
import pandas
import scipy

# %%
print(sys.version)
# Out:
# 3.6.7 (default, Feb 28 2019, 07:28:18) [MSC v.1900 64 bit (AMD64)]

# %%
print("Python: {}".format(sys.version))
print("Numpy: {}".format(numpy.__version__))
print("Matplotlib: {}".format(matplotlib.__version__))
print("Seaborn: {}".format(seaborn.__version__))
print("Sklearn: {}".format(sklearn.__version__))
print("Pandas: {}".format(pandas.__version__))
print("Scipy: {}".format(scipy.__version__))
# Out:
# Python: 3.6.7 (default, Feb 28 2019, 07:28:18) [MSC v.1900 64 bit (AMD64)]
# Numpy: 1.16.2
# Matplotlib: 3.0.3
# Seaborn: 0.9.0
# Sklearn: 0.20.3
# Pandas: 0.24.2
# Scipy: 1.2.1

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
data=pd.read_csv('creditcard.csv')

# %%
data.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
#         V26       V27       V28  Amount  Class
# 0 -0.189115  0.133558 -0.021053  149.62      0
# 1  0.125895 -0.008983  0.014724    2.69      0
# 2 -0.139097 -0.055353 -0.059752  378.66      0
# 3 -0.221929  0.062723  0.061458  123.50      0
# 4  0.502292  0.219422  0.215153   69.99      0
#
# [5 rows x 31 columns]

# %%
data.shape
# Out:
# (284807, 31)

# %%
data=data.sample(frac=0.4,random_state=1)

# %%
data.shape
# Out:
# (113923, 31)

# %%
data.head()
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 169876  119907.0 -0.611712 -0.769705 -0.149759 -0.224877  2.028577 -2.019887
# 127467   78340.0 -0.814682  1.319219  1.329415  0.027273 -0.284871 -0.653985
# 137900   82382.0 -0.318193  1.118618  0.969864 -0.127052  0.569563 -0.532484
# 21513    31717.0 -1.328271  1.018378  1.775426 -1.574193 -0.117696 -0.457733
# 134700   80923.0  1.276712  0.617120 -0.578014  0.879173  0.061706 -1.472002
#
#               V7        V8        V9  ...       V21       V22       V23  \
# 169876  0.292491 -0.523020  0.358468  ... -0.075208  0.045536  0.380739
# 127467  0.321552  0.435975 -0.704298  ... -0.128619 -0.368565  0.090660
# 137900  0.706252 -0.064966 -0.463271  ... -0.305402 -0.774704 -0.123884
# 21513   0.681867 -0.031641  0.383872  ... -0.220815 -0.419013 -0.239197
# 134700  0.373692 -0.287204 -0.084482  ... -0.160161 -0.430404 -0.076738
#
#              V24       V25       V26       V27       V28  Amount  Class
# 169876  0.023440 -2.220686 -0.201146  0.066501  0.221180    1.79      0
# 127467  0.401147 -0.261034  0.080621  0.162427  0.059456    1.98      0
# 137900 -0.495687 -0.018148  0.121679  0.249050  0.092516    0.89      0
# 21513   0.009967  0.232829  0.814177  0.098797 -0.004273   15.98      0
# 134700  0.258708  0.552170  0.370701 -0.034255  0.041709    0.76      0
#
# [5 rows x 31 columns]

# %%
data.hist(figsize=(20,20))
plt.show()

# %%
nonfraud=data[data['Class']==0]

# %%
fraud=data[data['Class']==1]

# %%
nonfraud.describe()
# Out:
#                 Time             V1             V2             V3  \
# count  113737.000000  113737.000000  113737.000000  113737.000000
# mean    94536.975654       0.012036      -0.003688       0.015502
# std     47523.127568       1.923788       1.642731       1.455839
# min         0.000000     -56.407510     -72.715728     -33.680984
# 25%     53950.000000      -0.914829      -0.601445      -0.872222
# 50%     84507.000000       0.026386       0.065934       0.183935
# 75%    139080.000000       1.316126       0.805408       1.027579
# max    172784.000000       2.451888      18.902453       4.069865
#
#                   V4             V5             V6             V7  \
# count  113737.000000  113737.000000  113737.000000  113737.000000
# mean       -0.001809       0.000664      -0.000174       0.004195
# std         1.400347       1.352942       1.323671       1.163207
# min        -5.560118     -42.147898     -26.160506     -26.548144
# 25%        -0.848017      -0.694390      -0.766894      -0.554779
# 50%        -0.017589      -0.059163      -0.271825       0.039113
# 75%         0.744861       0.609224       0.397371       0.566012
# max        16.715537      34.801666      22.529298      36.677268
#
#                   V8             V9  ...            V21            V22  \
# count  113737.000000  113737.000000  ...  113737.000000  113737.000000
# mean        0.001611       0.005745  ...      -0.000771      -0.000474
# std         1.148099       1.086875  ...       0.710979       0.722000
# min       -50.943369      -6.105803  ...     -22.665685     -10.933144
# 25%        -0.206005      -0.639071  ...      -0.228213      -0.542514
# 50%         0.023918      -0.047858  ...      -0.030216       0.005713
# 75%         0.326739       0.602151  ...       0.184735       0.527951
# max        18.282168      10.370658  ...      22.588989       7.220158
#
#                  V23            V24            V25            V26  \
# count  113737.000000  113737.000000  113737.000000  113737.000000
# mean        0.000204      -0.000762       0.000310       0.001785
# std         0.626742       0.603688       0.517960       0.481958
# min       -36.666000      -2.836627      -7.025783      -2.534330
# 25%        -0.161190      -0.354461      -0.317338      -0.326167
# 50%        -0.011048       0.040491       0.015187      -0.051004
# 75%         0.147951       0.435358       0.350069       0.243210
# max        22.528412       4.022866       6.070850       3.220178
#
#                  V27            V28         Amount     Class
# count  113737.000000  113737.000000  113737.000000  113737.0
# mean        0.000700      -0.001188      88.138078       0.0
# std         0.391748       0.319437     246.363006       0.0
# min        -9.390980      -9.617915       0.000000       0.0
# 25%        -0.070461      -0.052762       5.770000       0.0
# 50%         0.001508       0.011143      22.020000       0.0
# 75%         0.090417       0.077389      77.500000       0.0
# max        12.152401      33.847808   19656.530000       0.0
#
# [8 rows x 31 columns]

# %%
# Out:
# Time      0.001635
# V1        0.001635
# V2        0.001635
# V3        0.001635
# V4        0.001635
# V5        0.001635
# V6        0.001635
# V7        0.001635
# V8        0.001635
# V9        0.001635
# V10       0.001635
# V11       0.001635
# V12       0.001635
# V13       0.001635
# V14       0.001635
# V15       0.001635
# V16       0.001635
# V17       0.001635
# V18       0.001635
# V19       0.001635
# V20       0.001635
# V21       0.001635
# V22       0.001635
# V23       0.001635
# V24       0.001635
# V25       0.001635
# V26       0.001635
# V27       0.001635
# V28       0.001635
# Amount    0.001635
# Class     0.001635
# dtype: float64

# %%
columns=data.columns.tolist()

# %%
columns=[c for c in columns if c!='Class']

# %%
columns
# Out:
# ['Time',
#  'V1',
#  'V2',
#  'V3',
#  'V4',
#  'V5',
#  'V6',
#  'V7',
#  'V8',
#  'V9',
#  'V10',
#  'V11',
#  'V12',
#  'V13',
#  'V14',
#  'V15',
#  'V16',
#  'V17',
#  'V18',
#  'V19',
#  'V20',
#  'V21',
#  'V22',
#  'V23',
#  'V24',
#  'V25',
#  'V26',
#  'V27',
#  'V28',
#  'Amount']

# %%
corrmat=data.corr()

# %%
fig=plt.figure(figsize=(12,12))

# %%
sns.heatmap(corrmat,vmax=0.8,square=False)
plt.show()

# %%
import matplotlib.pyplot as plt
names = ['group_a', 'group_b', 'group_c']
values = [1, 10, 100]

#plt.figure(figsize=(9, 3))

plt.subplot(131)
plt.bar(names, values)
plt.subplot(132)
plt.scatter(names, values)
plt.subplot(133)
plt.plot(names, values)
plt.suptitle('Categorical Plotting')
plt.show()

# %%
import numpy as np
def f(t):
    return np.exp(-t) * np.cos(2*np.pi*t)

t1 = np.arange(0.0, 5.0, 0.1)
t2 = np.arange(0.0, 5.0, 0.02)


plt.subplot(221)
plt.plot(t1, f(t1), 'bo', t2, f(t2), 'k')
plt.xlabel("X axis")
plt.ylabel("Y axis")

plt.subplot(222)
plt.plot(t2, np.cos(2*np.pi*t2), 'r--')
plt.show()

# %%
import matplotlib.pyplot as plt
               # the first figure
plt.subplot(211)             # the first subplot in the first figure
plt.plot([1, 2, 3])
plt.subplot(212)             # the second subplot in the first figure
plt.plot([4, 5, 6])


               # a second figure
plt.plot([4, 5, 6])          # creates a subplot(111) by default

# figure 1 current; subplot(212) still current
plt.subplot(211)             # make subplot(211) in figure1 current
plt.title('Easy as 1, 2, 3') # subplot 211 title
# Out:
# Text(0.5, 1.0, 'Easy as 1, 2, 3')

# %%
import sklearn

# %%
from sklearn.datasets import load_digits

# %%
digits=load_digits()

# %%
digits.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\sklearn\utils\__init__.py in __getattr__(self, key)
#     101         try:
# --> 102             return self[key]
#     103         except KeyError:
#
# KeyError: 'head'
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# <ipython-input-22-91f13684e4e8> in <module>
# ----> 1 digits.head()
#
# ~\Anaconda3\lib\site-packages\sklearn\utils\__init__.py in __getattr__(self, key)
#     102             return self[key]
#     103         except KeyError:
# --> 104             raise AttributeError(key)
#     105
#     106     def __setstate__(self, state):
#
# AttributeError: head

# %%
from sklearn.model_selection import train_test_split

# %%
data.columns
# Out:
# Index(['Time', 'V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10',
#        'V11', 'V12', 'V13', 'V14', 'V15', 'V16', 'V17', 'V18', 'V19', 'V20',
#        'V21', 'V22', 'V23', 'V24', 'V25', 'V26', 'V27', 'V28', 'Amount',
#        'Class'],
#       dtype='object')

# %%
X=data.iloc[:,:30]

# %%
Y=data.Class

# %%
Y
# Out:
# 169876    0
# 127467    0
# 137900    0
# 21513     0
# 134700    0
# 196117    0
# 24533     0
# 13629     0
# 246673    0
# 91842     0
# 33014     0
# 14195     0
# 11682     0
# 956       0
# 235714    0
# 114485    0
# 147061    0
# 29839     0
# 50220     0
# 14065     0
# 272241    0
# 246321    0
# 258176    0
# 174037    0
# 80136     0
# 280769    0
# 279634    0
# 176242    0
# 101528    0
# 91593     0
#          ..
# 270356    0
# 139316    0
# 182169    0
# 13321     0
# 205420    0
# 49013     0
# 210038    0
# 270986    0
# 236258    0
# 208255    0
# 82309     0
# 84245     0
# 44811     0
# 272157    0
# 119092    0
# 30023     0
# 246026    0
# 32463     0
# 185800    0
# 243888    0
# 13701     0
# 131329    0
# 24222     0
# 89432     0
# 167417    0
# 134115    0
# 132008    0
# 179997    0
# 156224    0
# 254568    0
# Name: Class, Length: 113923, dtype: int64

# %%
x_train,x_test,y_train,y_test=train_test_split(X,Y,test_size=0.25,random_state=0)

# %%
x_train
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 139162   83043.0  1.344348 -1.246953 -0.261864 -1.514119 -1.031967 -0.353360
# 74028    55392.0  1.235186  0.097507 -0.110233  0.132614 -0.087203 -0.723000
# 147037   88055.0  2.095935 -0.051448 -1.474070  0.036232  0.537662 -0.244691
# 46805    42935.0 -0.963656  0.743462  1.557434  0.189076 -0.166781 -0.688312
# 104048   68893.0  1.374345 -0.482392  0.036235 -0.716462 -0.936730 -1.206886
# 177359  123145.0  1.991922  0.225554 -1.386770  1.665105  0.105445 -0.989829
# 262913  160710.0  1.876679 -0.155204 -1.748219  0.498272  0.003679 -1.178741
# 48948    43850.0  1.194177  0.388599  0.685499  1.177447 -0.501604 -1.057594
# 170041  119991.0  2.091460 -0.191352 -1.514553  0.055616  0.370059 -0.288370
# 247632  153641.0 -0.382338  0.584649  0.881102 -0.919542  1.105793 -0.505984
# 186342  127060.0  0.667110  0.552175 -0.924040 -0.852436  0.711257 -0.626963
# 247668  153651.0 -2.680950  3.050218 -0.642816 -1.530101  0.730891 -0.958912
# 152633   97426.0  1.945502 -0.433425  0.163102  0.373704 -0.747171  0.071066
# 151922   96501.0  1.633829 -0.828772 -0.693180  0.249212  0.141063  1.408749
# 165100  117197.0  0.161617  0.867985 -0.801035 -0.874493  1.352667  0.077033
# 196213  131408.0 -0.039683  0.094316  0.788427 -0.016608  0.547742  0.003007
# 169188  0.168176  0.537470 -0.175428  0.023784  0.428172 -0.281084     9.86
# 189657  0.381043 -0.384039 -1.262462  0.658618  0.297277 -0.254332    50.00
# 226872 -0.076187  0.056956 -0.361371  0.425313 -0.150166 -0.074096    33.25
# 89011  -0.143115 -0.392804 -0.116567  0.772185  0.181056  0.059970     2.23
# 144294  0.053762  0.484560  0.405577 -0.551818  0.022756  0.016959    15.05
# 237311  0.300913 -0.467174 -0.572961 -0.226035  0.055179 -0.046194    10.00
# 284292 -0.108140 -0.317233  0.397446 -0.095046 -0.030390 -0.073033     0.99
# 157770 -0.035168 -0.993685 -0.336272  0.642144 -0.327290  0.215538     1.79
# 90164  -0.154821  0.050529  0.208184  1.086346 -0.104466  0.017724   214.96
# 158857 -0.346940 -0.708612  1.419549 -0.181709  0.122695  0.149269     4.51
# 86567   0.205350 -0.603882 -0.124351  0.426631  0.084587  0.014844    10.29
# 264706 -0.159720  0.051589 -0.330515  0.078462 -0.053515  0.111964    20.00
# 210423  0.131452 -0.707684 -0.490349 -0.168632  0.002232 -0.001744   152.19
# 47140  -0.168846 -0.294142 -0.073927 -0.218374  0.303936  0.097982     1.00
# 192825 -0.875277 -0.064079 -0.174992 -0.199931 -0.196617  0.138839  1000.00
# 193472 -0.353403 -0.108238 -0.033200 -0.064341  0.159694  0.188355     4.00
# 68263   0.006146 -0.391612  0.295629  0.897963 -0.085714 -0.004026     0.00
# 49305  -0.090941  0.035727 -0.177960  0.297483  0.172653  0.104678     1.00
# 79517  -0.027184 -0.352772  0.039440  0.818481 -0.453333 -0.328685   110.00
# 96234   0.002523  0.750606  0.610701 -0.481175  0.041171  0.030015     8.39
# 66756  -0.125256 -0.420751  0.571979 -0.361214  0.080178  0.032717     9.99
# 240938 -0.236624  0.627052  0.496414 -0.408003  0.143809  0.027590    79.00
# 134058 -0.042086  0.058682 -0.182610 -0.274816  0.133396  0.109147    14.00
# 130841  0.133867  0.046437  0.151226  0.164644 -0.067077  0.014913    70.90
# 13803  -0.065533 -1.080758 -0.723815 -0.587359 -0.233201 -0.031359    78.00
# 280934 -0.033392  0.826427 -0.691981 -0.271837  0.496524  0.314239    18.78
#
# [85442 rows x 30 columns]

# %%
x_test.shape
# Out:
# (28481, 30)

# %%
from sklearn.linear_model import LogisticRegression

# %%
logisticreg=LogisticRegression()

# %%
logisticreg.fit(x_train,y_train)
# Out:
# C:\Users\kunal virmani\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=None, solver='warn',
#           tol=0.0001, verbose=0, warm_start=False)

# %%
y_pred=logisticreg.predict(x_test)

# %%
y_pred
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int64)

# %%
y_pred.count()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-50-cdaa913c0147> in <module>
# ----> 1 y_pred.count()
#
# AttributeError: 'numpy.ndarray' object has no attribute 'count'

# %%
y_pred.shape
# Out:
# (7121,)

# %%
y_test.shape
# Out:
# (7121,)

# %%
count=0
pos=[c for c in y_pred if c==1]

# %%
pos
# Out:
# [1, 1, 1, 1, 1, 1, 1, 1]

# %%
pos.length()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-59-f80ceb061b8f> in <module>
# ----> 1 pos.length()
#
# AttributeError: 'list' object has no attribute 'length'

# %%
len(pos)
# Out:
# 8

# %%
rpos=[c for c in y_test if c==1]

# %%
len(rpos)
# Out:
# 11

# %%
from sklearn.metrics import accuracy_score

# %%
score=accuracy_score(y_test,y_pred)

# %%
score
# Out:
# 0.9987711105649381
