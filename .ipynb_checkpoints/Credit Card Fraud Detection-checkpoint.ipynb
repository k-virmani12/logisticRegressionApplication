# %%
import sys
import numpy
import matplotlib
import seaborn
import sklearn
import pandas
import scipy

# %%
print(sys.version)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-c4f95efce128> in <module>
# ----> 1 print(sys.version)
#
# NameError: name 'sys' is not defined

# %%
print("Python: {}".format(sys.version))
print("Numpy: {}".format(numpy.__version__))
print("Matplotlib: {}".format(matplotlib.__version__))
print("Seaborn: {}".format(seaborn.__version__))
print("Sklearn: {}".format(sklearn.__version__))
print("Pandas: {}".format(pandas.__version__))
print("Scipy: {}".format(scipy.__version__))
# Out:
# Python: 3.6.7 (default, Feb 28 2019, 07:28:18) [MSC v.1900 64 bit (AMD64)]
# Numpy: 1.16.2
# Matplotlib: 3.0.3
# Seaborn: 0.9.0
# Sklearn: 0.20.3
# Pandas: 0.24.2
# Scipy: 1.2.1

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
data=pd.read_csv('creditcard.csv')

# %%
data.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
#         V26       V27       V28  Amount  Class
# 0 -0.189115  0.133558 -0.021053  149.62      0
# 1  0.125895 -0.008983  0.014724    2.69      0
# 2 -0.139097 -0.055353 -0.059752  378.66      0
# 3 -0.221929  0.062723  0.061458  123.50      0
# 4  0.502292  0.219422  0.215153   69.99      0
#
# [5 rows x 31 columns]

# %%
data.shape
# Out:
# (284807, 31)

# %%
rows=data.shape[0]

# %%
rows
# Out:
# 284807

# %%
0.1*rows
# Out:
# 28480.7

# %%
round(0.1*rows)
# Out:
# 28481

# %%
data=data.sample(28481)

# %%
data.shape
# Out:
# (28481, 31)

# %%
data.head()
# Out:
#            Time        V1        V2        V3        V4        V5        V6  \
# 90734   63146.0  1.165197 -0.358873  0.877320  1.231902 -0.312499  1.509925
# 143584  85461.0  1.439593 -1.148371  0.405245 -1.476581 -1.440699 -0.266700
# 112003  72473.0 -1.402516  1.588247  0.677983  0.559932 -0.008249 -0.123322
# 50810   44660.0  1.216994 -0.080435 -0.055810 -0.866514 -0.241992 -0.708585
# 129156  78973.0 -1.641340  3.564076 -2.820339  1.147451  0.177460 -2.264140
#
#               V7        V8        V9  ...       V21       V22       V23  \
# 90734  -0.905214  0.433706  1.559596  ... -0.011130  0.468127 -0.324319
# 143584 -1.203028  0.127075 -1.868741  ... -0.155689 -0.125159  0.074132
# 112003  0.360224  0.457656 -0.086353  ...  0.063092  0.586173 -0.032315
# 50810   0.144855 -0.113245  0.790931  ...  0.081764  0.535972 -0.160179
# 129156  0.786582 -0.116708  1.882366  ... -0.454763 -0.437487  0.282707
#
#              V24       V25       V26       V27       V28  Amount  Class
# 90734  -1.256038  0.812988 -0.023793  0.107254  0.016532   14.69      0
# 143584 -0.036033  0.232782 -0.188673  0.032905  0.003438   10.00      0
# 112003 -0.008219 -0.162719 -0.311386  0.448390  0.138588    8.19      0
# 50810   0.284098  0.855307 -0.552496  0.054370  0.001291    1.00      0
# 129156  0.287475  0.026470 -0.368437  1.398255  0.682074    0.89      0
#
# [5 rows x 31 columns]

# %%
data.hist(figsize=(20,20))
plt.show()

# %%
nonfraud=data[data['Class']==0]

# %%
fraud=data[data['Class']==1]

# %%
nonfraud.describe()
# Out:
#                 Time            V1            V2            V3            V4  \
# count   28431.000000  28431.000000  28431.000000  28431.000000  28431.000000
# mean    95124.550983      0.003847     -0.008357      0.008385     -0.010866
# std     47610.688020      1.954111      1.677951      1.463843      1.396565
# min        16.000000    -56.407510    -72.715728    -32.454198     -5.231828
# 25%     54059.000000     -0.923646     -0.591530     -0.896950     -0.853663
# 50%     85383.000000      0.012318      0.065023      0.176412     -0.022893
# 75%    139627.500000      1.316834      0.794180      1.032449      0.737333
# max    172784.000000      2.439207     17.930550      4.017561     16.491217
#
#                  V5            V6            V7            V8            V9  \
# count  28431.000000  28431.000000  28431.000000  28431.000000  28431.000000
# mean       0.017950     -0.002000      0.015418      0.008613      0.004856
# std        1.333175      1.328499      1.147255      1.132434      1.090745
# min      -23.236403    -26.160506    -22.030417    -28.035838     -4.362249
# 25%       -0.679622     -0.769248     -0.547906     -0.207070     -0.635344
# 50%       -0.048344     -0.275032      0.049843      0.021658     -0.051667
# 75%        0.613007      0.390501      0.576516      0.324625      0.585953
# max       34.801666     13.461737     23.718783     18.282168      9.234623
#
#        ...           V21           V22           V23           V24  \
# count  ...  28431.000000  28431.000000  28431.000000  28431.000000
# mean   ...      0.001127      0.003317      0.007242      0.001757
# std    ...      0.731418      0.724350      0.638831      0.604141
# min    ...    -14.058810     -8.245481    -27.533643     -2.822684
# 25%    ...     -0.228221     -0.544942     -0.160899     -0.354445
# 50%    ...     -0.029440      0.006762     -0.010123      0.041278
# 75%    ...      0.186147      0.535038      0.148754      0.443422
# max    ...     21.899724      4.799794     20.803344      3.926604
#
#                 V25           V26           V27           V28        Amount  \
# count  28431.000000  28431.000000  28431.000000  28431.000000  28431.000000
# mean       0.001227      0.001895     -0.002661      0.001705     88.134738
# std        0.520529      0.482070      0.399958      0.365185    235.506411
# min       -3.856097     -1.405933     -9.845808     -8.233983      0.000000
# 25%       -0.318066     -0.326198     -0.071808     -0.053478      5.640000
# 50%        0.018415     -0.050504      0.000233      0.010457     22.000000
# 75%        0.351036      0.242091      0.090253      0.077218     76.225000
# max        5.826159      3.517346      7.138240     33.847808   6652.890000
#
#          Class
# count  28431.0
# mean       0.0
# std        0.0
# min        0.0
# 25%        0.0
# 50%        0.0
# 75%        0.0
# max        0.0
#
# [8 rows x 31 columns]

# %%
columns=data.columns.tolist()

# %%
columns=[c for c in columns if c!='Class']

# %%
columns
# Out:
# ['Time',
#  'V1',
#  'V2',
#  'V3',
#  'V4',
#  'V5',
#  'V6',
#  'V7',
#  'V8',
#  'V9',
#  'V10',
#  'V11',
#  'V12',
#  'V13',
#  'V14',
#  'V15',
#  'V16',
#  'V17',
#  'V18',
#  'V19',
#  'V20',
#  'V21',
#  'V22',
#  'V23',
#  'V24',
#  'V25',
#  'V26',
#  'V27',
#  'V28',
#  'Amount']

# %%
corrmat=data.corr()

# %%
fig=plt.figure(figsize=(12,12))

# %%
sns.heatmap(corrmat,vmax=0.8,square=False)
plt.show()

# %%
import matplotlib.pyplot as plt
names = ['group_a', 'group_b', 'group_c']
values = [1, 10, 100]

#plt.figure(figsize=(9, 3))

plt.subplot(131)
plt.bar(names, values)
plt.subplot(132)
plt.scatter(names, values)
plt.subplot(133)
plt.plot(names, values)
plt.suptitle('Categorical Plotting')
plt.show()

# %%
import numpy as np
def f(t):
    return np.exp(-t) * np.cos(2*np.pi*t)

t1 = np.arange(0.0, 5.0, 0.1)
t2 = np.arange(0.0, 5.0, 0.02)


plt.subplot(221)
plt.plot(t1, f(t1), 'bo', t2, f(t2), 'k')
plt.xlabel("X axis")
plt.ylabel("Y axis")

plt.subplot(222)
plt.plot(t2, np.cos(2*np.pi*t2), 'r--')
plt.show()

# %%
import matplotlib.pyplot as plt
               # the first figure
plt.subplot(211)             # the first subplot in the first figure
plt.plot([1, 2, 3])
plt.subplot(212)             # the second subplot in the first figure
plt.plot([4, 5, 6])


               # a second figure
plt.plot([4, 5, 6])          # creates a subplot(111) by default

# figure 1 current; subplot(212) still current
plt.subplot(211)             # make subplot(211) in figure1 current
plt.title('Easy as 1, 2, 3') # subplot 211 title
# Out:
# Text(0.5, 1.0, 'Easy as 1, 2, 3')

# %%
import sklearn

# %%
from sklearn.datasets import load_digits

# %%
digits=load_digits()

# %%
digits.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\sklearn\utils\__init__.py in __getattr__(self, key)
#     101         try:
# --> 102             return self[key]
#     103         except KeyError:
#
# KeyError: 'head'
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# <ipython-input-22-91f13684e4e8> in <module>
# ----> 1 digits.head()
#
# ~\Anaconda3\lib\site-packages\sklearn\utils\__init__.py in __getattr__(self, key)
#     102             return self[key]
#     103         except KeyError:
# --> 104             raise AttributeError(key)
#     105
#     106     def __setstate__(self, state):
#
# AttributeError: head

# %%
from sklearn.model_selection import train_test_split

# %%
data.columns
# Out:
# Index(['Time', 'V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10',
#        'V11', 'V12', 'V13', 'V14', 'V15', 'V16', 'V17', 'V18', 'V19', 'V20',
#        'V21', 'V22', 'V23', 'V24', 'V25', 'V26', 'V27', 'V28', 'Amount',
#        'Class'],
#       dtype='object')

# %%
X=data.iloc[:,:30]

# %%
Y=data.Class

# %%
Y
# Out:
# 90734     0
# 143584    0
# 112003    0
# 50810     0
# 129156    0
# 34858     0
# 183489    0
# 126205    0
# 189087    0
# 261475    0
# 173842    0
# 104232    0
# 141063    0
# 42271     0
# 129486    0
# 169876    0
# 125365    0
# 234424    0
# 150531    0
# 44946     0
# 70280     0
# 136089    0
# 118611    0
# 69986     0
# 70430     0
# 164511    0
# 45682     0
# 56564     0
# 139268    0
# 72325     0
#          ..
# 78261     0
# 202098    0
# 91998     0
# 207571    0
# 81072     0
# 43539     0
# 191998    0
# 181195    0
# 75894     0
# 163984    0
# 25975     0
# 95310     0
# 156416    0
# 274740    0
# 192885    0
# 112004    0
# 141181    0
# 271910    0
# 43995     0
# 208107    0
# 28105     0
# 206923    0
# 210057    0
# 109906    0
# 143280    0
# 234043    0
# 120404    0
# 8742      0
# 39016     0
# 241386    0
# Name: Class, Length: 28481, dtype: int64

# %%
x_train,x_test,y_train,y_test=train_test_split(X,Y,test_size=0.25,random_state=0)

# %%
x_train
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 244327  152304.0  1.913027 -0.032529 -1.890784  0.067097  1.254273  1.145674
# 257262  158078.0  2.084021  0.789080 -3.017180  0.795187  1.159874 -1.840323
# 97472    66234.0  1.274467 -0.603658  0.629590 -0.806825 -0.915312 -0.154505
# 95809    65477.0 -1.085961  0.760944  1.100130  1.378799 -0.151223  0.088930
# 191190  129152.0  2.064301 -1.058369 -2.559613 -1.651716  1.597013  3.419619
# 96885    65984.0 -1.817044  0.835208 -0.398737  0.225296 -4.868917  1.812740
# 82803    59557.0  1.202244  1.176249 -1.636250  1.608445  0.930122 -1.386088
# 51554    45005.0 -0.693827  1.631412  1.330670  3.345941  1.235674  0.103725
# 86543    61279.0 -0.883666  0.392352  1.189383 -0.614726 -1.013892 -0.105872
# 254783  156914.0  1.823321  0.375947 -0.765383  3.661506  0.534521  0.377147
# 64163    51057.0 -0.759081 -0.689920  1.500641 -2.782239 -0.656259  0.216013
# 254471  156746.0 -0.978718  1.174864 -0.459918 -0.567547 -0.122295 -0.889930
# 251575  155400.0  1.987602 -0.499636 -0.597271  0.291496 -0.396584  0.006908
# 127247   78262.0 -3.807095  2.524134 -0.941965 -0.524478  1.014881 -1.495083
# 187842  127713.0 -0.248357  0.900580 -0.325489 -0.168654  0.744021 -1.318814
# 166329  118006.0 -0.383987  1.728894 -0.406420  4.293512  0.758913  0.407827
# 17539    28802.0 -3.544332  2.374676 -2.634764  1.120777 -1.870876 -0.655045
# 107056   70262.0  1.202712 -0.106301  0.781003  0.464944 -0.753298 -0.249591
# 59914    49064.0 -0.717866  0.704279  1.401668  2.730985  1.090474  0.587096
# 25038   0.009763 -0.096835 -0.097054  0.678952 -0.084776  0.055189   238.63
# 88867  -0.230180 -0.313768 -0.388918 -0.107293  0.032974 -0.078763     4.77
# 56628  -0.209294 -0.493059  0.688102  0.460669  0.005905  0.036338    12.31
# 117132 -0.096477  0.991231 -0.358552 -0.179841 -0.230524 -0.074773    20.00
# 103656  0.203118  0.614607 -0.175311  0.057170  0.249950  0.126949     3.57
# 51019   0.133869  0.664151  0.292469 -0.218466 -0.012278  0.029214     6.24
# 234000 -0.300341  0.476210 -0.001607 -0.195050 -0.185266 -0.131026     1.00
# 24120  -0.226644  0.392797  0.431955  0.077693  0.079763  0.029503    79.00
# 24889  -0.344275 -0.197627  0.496458  0.183961  0.031200  0.035112   200.00
# 217445  0.013432 -0.421190 -0.476611  0.145942  0.240856  0.082718     3.59
# 32799   0.175289 -0.560708  0.134177 -0.433563  0.043437  0.106751   124.75
# 187089 -0.316355  0.281567  0.711350 -0.154614  0.077823 -0.016888   114.00
# 107134 -0.094263 -0.785162  0.389064 -0.042789  0.072277  0.006655     6.00
# 105243 -0.066208 -0.037937 -0.207809  0.076802  0.255887  0.105844     1.79
# 49936   0.245463  0.292547 -0.247697 -0.455755  0.048144 -0.035704   285.70
# 248664  0.605189 -0.573320  0.247212 -0.673775 -0.157714 -0.137325   264.59
# 182309  0.182099  0.571680 -0.136771 -0.142096 -0.026641 -0.016992    62.20
# 238444  0.230318 -1.065808 -0.595570  0.205708  0.007205  0.054339     0.99
# 113091  0.126063 -0.394596  0.099897  0.132686 -0.021874  0.010276     1.79
# 119001  0.151215  0.590042 -0.422841  1.065987 -0.136942  0.024550    84.99
# 127910 -0.094327  0.238477  0.592335 -0.347940  0.028136  0.016562    57.00
# 166533 -0.212509  0.536422  0.776939  0.288023 -0.109786 -0.092464    10.00
# 21525  -0.236939 -1.351477  0.419478 -0.122713  0.073753  0.031411    53.53
# 49716  -0.798062 -0.504211  0.703165 -0.087215 -0.141633  0.093813   598.95
# 257515 -0.146182  0.102782  0.626423 -0.433098 -0.053102 -0.070814    36.00
#
# [21360 rows x 30 columns]

# %%
x_test.shape
# Out:
# (7121, 30)

# %%
from sklearn.linear_model import LogisticRegression

# %%
logisticreg=LogisticRegression()

# %%
logisticreg.fit(x_train,y_train)
# Out:
# C:\Users\kunal virmani\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=None, solver='warn',
#           tol=0.0001, verbose=0, warm_start=False)

# %%
y_pred=logisticreg.predict(x_test)

# %%
y_pred
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int64)

# %%
y_pred.count()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-50-cdaa913c0147> in <module>
# ----> 1 y_pred.count()
#
# AttributeError: 'numpy.ndarray' object has no attribute 'count'

# %%
y_pred.shape
# Out:
# (7121,)

# %%
y_test.shape
# Out:
# (7121,)

# %%
count=0
pos=[c for c in y_pred if c==1]

# %%
pos
# Out:
# [1, 1, 1, 1, 1, 1, 1, 1]

# %%
pos.length()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-59-f80ceb061b8f> in <module>
# ----> 1 pos.length()
#
# AttributeError: 'list' object has no attribute 'length'

# %%
len(pos)
# Out:
# 8

# %%
rpos=[c for c in y_test if c==1]

# %%
len(rpos)
# Out:
# 11

# %%
from sklearn.metrics import accuracy_score

# %%
score=accuracy_score(y_test,y_pred)

# %%
score
# Out:
# 0.9990169919955062
